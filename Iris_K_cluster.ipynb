# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load the dataset from CSV
file_path = r"C:\Users\Swapnali\Desktop\Data_ML\IRIS.csv"  # Update with your actual username
data = pd.read_csv(file_path)

# Select sepal length and width columns
sepal_data = data[['sepal_length', 'sepal_width']]

# Standardize the features
scaler = StandardScaler()
sepal_scaled = scaler.fit_transform(sepal_data)

# Perform k-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(sepal_scaled)

# Add the cluster labels to the dataset
data['cluster'] = kmeans.labels_

# Plot the data points on a scatter plot
plt.figure(figsize=(10, 6))

# Scatter plot for each cluster
for cluster in range(3):
    plt.scatter(sepal_scaled[data['cluster'] == cluster, 0], sepal_scaled[data['cluster'] == cluster, 1], label=f'Cluster {cluster}')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color='black', marker='x', label='Centroids')
plt.xlabel('Sepal Length (Standardized)')
plt.ylabel('Sepal Width (Standardized)')
plt.title('K-Means Clustering of Iris Sepal Data')
plt.legend()
plt.show()
# Out:
# C:\Users\Swapnali\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
